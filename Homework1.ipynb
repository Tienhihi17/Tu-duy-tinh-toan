# %% [markdown]
# ### Bài 1
# Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
n = n*2
print(n)
# Out:
# 10

# %% [markdown]
# ### Bài 2
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân

# %%
a = float(input("Nhập chiều rộng a: "))
b = float(input("Nhập chiều dài b: "))

dien_tich_hcn = a * b
# Bán kính hình tròn bằng nửa chiều rộng
r = a / 2
dien_tich_tron = 3.14 * (r ** 2)

dien_tich_con_lai = dien_tich_hcn - dien_tich_tron
print(f"{dien_tich_con_lai:.2f}")
# Out:
# 7.44

# %% [markdown]
# ### Bài 3
#  Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường
# tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input("Nhập một ký tự: ")

if c.isupper():
    print(c.lower())
else:
    print(c.upper())

# %% [markdown]
# ### Bài 4
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet

# %%
c = input("Nhập một ký tự: ")

if c.isalpha():
    print(f"{c} là kí tu alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")

# %% [markdown]
# ### Bài 5
#  Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt

# %%
c = input("Nhập chữ cái hoa: ")

if c == 'A':
    print('z') # Hoặc ký tự đứng trước 'a' tùy theo yêu cầu cụ thể
else:
    # Chuyển hoa sang thường, lấy mã ASCII trừ đi 1, rồi chuyển lại thành ký tự
    chu_thuong_lien_truoc = chr(ord(c.lower()) - 1)
    print(chu_thuong_lien_truoc)

# %% [markdown]
# ### Bài 6
#  Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math

a = float(input())
b = float(input())
c = float(input())

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    s = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print(f"{s:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")

# %% [markdown]
# ### Bài 7
# Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
s = input("Nhập chuỗi (độ dài >= 20): ")

if len(s) >= 20:
    print(f"Ký tự thứ năm: {s[4]}")
    print(f"Ký tự thứ chín: {s[8]}")
else:
    print("Chuỗi quá ngắn!")

# %% [markdown]
# ### Bài 8
# Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:  -
# Từ 0 – 50kWh: 1.984 đồng/kWh  - - - - -
# Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh

# %%
# Nhập dữ liệu
ten_chu_ho = input("Ten chu ho: ")
chi_so_truoc = int(input("Chi so thang truoc: "))
chi_so_nay = int(input("Chi so thang nay: "))

# Tính số điện tiêu thụ
so_dien = chi_so_nay - chi_so_truoc
tien_dien = 0

# Tính tiền theo từng bậc (Lũy tiến)
if so_dien <= 50:
    tien_dien = so_dien * 1984
elif so_dien <= 100:
    tien_dien = 50 * 1984 + (so_dien - 50) * 2050
elif so_dien <= 200:
    tien_dien = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
elif so_dien <= 300:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
elif so_dien <= 400:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (so_dien - 300) * 3350
else:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460

# Tính thuế VAT 8%
tong_tien = tien_dien * 1.08

# In kết quả, làm tròn về đơn vị đồng (dùng int để lấy phần nguyên)
print(f"Ho va ten: {ten_chu_ho}")
print(f"Tien phai tra la: {int(tong_tien)}")
